# %% [markdown]
# # 4.7 Deriving New Variables

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing DataFrame

# %%
#  creating a string of the path for ordersproducts_merged.pkl file from main folder
path = r"C:/Users/Soni/7-7-23(Instacart Basket Analysis)"

# %%
#Importing orders_products_merged pickel file
df_ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
#create the subset of dataFrame
df = df_ords_prods_merged[:1000000]

# %%
# check the shape of dataFrame
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# ## If-Statements with User-Defined Functions

# %%
# Define If statement with Function: for price label flag
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
#Apply price label on DataFrame
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Soni\AppData\Local\Temp\ipykernel_9720\2763952047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
# Check max price to confirm
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## If-Statements with the loc() Function

# %% [markdown]
# **just applying loc() without using if-elif statements**

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Soni\AppData\Local\Temp\ipykernel_9720\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# **Now loc() on your entire dataframe**

# %%
# loc() on your entire DataFrame
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df_ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## If-Statements with For-Loops

# %%
# printing the frequency of the “orders_day_of_the_week” 
df_ords_prods_merged['order_dow'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: order_dow, dtype: int64

# %%
# plotting bar chart for this column:
bar_busiest day = ords_prods_combined['order_dow'].value_counts().plot.bar()

# %%
# for loop
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Results with DataFrame
df_ords_prods_merged['busiest_day'] = result

# %%
# check value counts
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# ## Exercise Task 2

# %%
# for loop for 2 busiest days and 2 least busy days
result = []

for value in df_ords_prods_merged["order_dow"]:
  if value == 0 or value == 1:
    result.append("Busiest day")
  elif value == 3 or value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
# put the result in new column:
df_ords_prods_merged['busiest_days'] = result

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# ...

# %% [markdown]
# ## Step 3: Check the values of this new column for accuracy.

# %%
# check value counts
df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest day       11864412
# Least busy         7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# **After checking Busiest day and least Busy day, result showing extra values in each column it means thease values add up**
# **When checked with our original frequency counts, these values add up to the sums of each "grouping". ie - the total for busiest days equals the sum of value 0 and value 1, and the values for least busy days adds to the sum of value 3 and 4, confirming that the loop operated correctly**

# %%
# Check
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge    price_range_loc  \
# 0         Soda        77              7     9.0   both  Mid-range product
# ...

# %% [markdown]
# ## Step 4:  busiest hours of the day(Create a new column containing these labels called “busiest_period_of_day.”)

# %%
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# **As client want maximum order according to hours so i divide order_hours according to frequency counts. Most orders = (10, 11, 14, 15, 13, 12, 16, 9) Average orders = (17, 8, 18, 19, 20, 7, 21, 22) Fewest orders =( 23, 6, 0, 1, 5, 2, 4, 3)**

# %%
hour_of_day = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in[10, 11, 14, 15, 13, 12, 16, 9]:
    hour_of_day.append("most orders")
 # elif value in[17, 8, 18, 19, 20, 7, 21, 22]:
  elif value in[23, 6, 0, 1, 5, 2, 4, 3]: 
    hour_of_day.append("fewest orders")
  else:
    hour_of_day.append("average orders")

# %%
# Add result to dataframe as "busiest_period_of_day" column
df_ords_prods_merged['busiest_period_of_day'] = hour_of_day

# %%
df_ords_prods_merged[['order_hour_of_day', 'busiest_period_of_day']].head(20)
# Out:
#     order_hour_of_day busiest_period_of_day
# 0                   8        average orders
# 1                   7        average orders
# 2                  12           most orders
# 3                   7        average orders
# 4                  15           most orders
# 5                   7        average orders
# 6                   9           most orders
# 7                  14           most orders
# 8                  16           most orders
# 9                   8        average orders
# 10                  9           most orders
# 11                 16           most orders
# 12                 11           most orders
# 13                  9           most orders
# 14                 10           most orders
# 15                 14           most orders
# 16                 12           most orders
# 17                 17        average orders
# 18                 10           most orders
# 19                  8        average orders

# %% [markdown]
# ## Step 5: Print Frequency

# %%
df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# most orders       21118071
# average orders     9997651
# fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# **These frequencies match the sums of the above "ungrouped" frequencies, confirming the correct application of the labels**

# %% [markdown]
# ## Step 7: Export as pickle file

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_updated.pkl'))
