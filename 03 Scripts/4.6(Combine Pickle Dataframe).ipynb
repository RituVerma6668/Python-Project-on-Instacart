# %% [markdown]
# # 4.6 Combined Pickle Dataframe

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing DataFrame

# %%
#  creating a string of the path for produt.csv main project folder
path = r"C:/Users/Soni/7-7-23(Instacart Basket Analysis)"

# %% [markdown]
# # Import products_checked file

# %%
#Importing orders_checked.csv dataframe
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)

# %% [markdown]
# # Question 3: Import Pickle Dataframe from file

# %%
df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ords_prods_combined
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32434484   2977660   206209            13          1                 12
# 32434485   2977660   206209            13          1                 12
# 32434486   2977660   206209            13          1                 12
# 32434487   2977660   206209            13          1                 12
# 32434488   2977660   206209            13          1                 12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# **Before merging products dataset I deleted _merge column , it was giving error for the process**

# %%
#Drop the unnecessary Column
df_ords_prods_combined = df_ords_prods_combined.drop(columns = ['_merge'])

# %%
df_ords_prods_combined
# Out:
#           order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0          2539329        1             1          2                  8
# 1          2539329        1             1          2                  8
# 2          2539329        1             1          2                  8
# 3          2539329        1             1          2                  8
# 4          2539329        1             1          2                  8
# ...            ...      ...           ...        ...                ...
# 32434484   2977660   206209            13          1                 12
# 32434485   2977660   206209            13          1                 12
# 32434486   2977660   206209            13          1                 12
# 32434487   2977660   206209            13          1                 12
# 32434488   2977660   206209            13          1                 12
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered
# ...

# %% [markdown]
# # Question 4: Dataframe Shape

# %%
#Check the shape of the imported dataframe
df_ords_prods_combined.shape
# Out:
# (32434489, 9)

# %% [markdown]
# Yes, this is exactly same as exported file.

# %% [markdown]
# # Question 5: products checked DataFrame

# %%
# products_checked DataFrame
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# Products_checked DataFrame shape
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods = df_prods.drop(columns =['Unnamed: 0'])

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
# combine both df_ords_prods_combined DataFrame and product_checked DataSet 
df_merged = df_ords_prods_combined.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# ...

# %% [markdown]
# # 6. Confirm the results of the merge using the merge flag.

# %%
# counts merge Flag- letting you see instantly whether you have a full match or not.
df_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# checking the merge shape
df_merged.shape
# Out:
# (32404859, 14)

# %% [markdown]
# # 7. Export the newly created dataframe as orders_products_merged in a suitable format

# %%
# Export df_merged in pickle format because of large data size.

df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged.pkl'))
